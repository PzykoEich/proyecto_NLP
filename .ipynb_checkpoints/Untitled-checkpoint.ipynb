# %% [markdown]
# # En este momento no se que debo hacer 😅

# %% [markdown]
# # Verificación de emociones

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf 
import nltk
import spacy
# Out:
# 2026-03-12 15:47:26.369067: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773352046.385113    3221 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773352046.390067    3221 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773352046.403068    3221 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773352046.403094    3221 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773352046.403096    3221 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773352046.403098    3221 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# !pip install kagglehub 
import kagglehub
# Out:
# Requirement already satisfied: kagglehub in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from kagglehub) (0.1.16)
# Requirement already satisfied: packaging in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (6.31.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from requests->kagglehub) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/martin/miniconda3/envs/ciencia/lib/python3.12/site-packages (from requests->kagglehub) (2026.2.25)

# %%
#Load data from kaggle 
path = kagglehub.dataset_download("jp797498e/twitter-entity-sentiment-analysis", path='twitter_training.csv')

# %%
df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 74681 entries, 0 to 74680
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   2401                                                   74681 non-null  int64
#  1   Borderlands                                            74681 non-null  str
#  2   Positive                                               74681 non-null  str
#  3   im getting on borderlands and i will murder you all ,  73995 non-null  str
# dtypes: int64(1), str(3)
# memory usage: 2.3 MB

# %%
df
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...
#
# [74681 rows x 4 columns]

# %%
df['Positive'].value_counts()
# Out:
# Positive
# Negative      22542
# Positive      20831
# Neutral       18318
# Irrelevant    12990
# Name: count, dtype: int64

# %%
df['Positive']
# Out:
# 0        Positive
# 1        Positive
# 2        Positive
# 3        Positive
# 4        Positive
#            ...
# 74676    Positive
# 74677    Positive
# 74678    Positive
# 74679    Positive
# 74680    Positive
# Name: Positive, Length: 74681, dtype: str
